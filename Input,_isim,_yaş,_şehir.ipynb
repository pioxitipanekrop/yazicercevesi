# %% [markdown]
# <a href="https://colab.research.google.com/github/pioxitipanekrop/yazicercevesi/blob/main/Input%2C_isim%2C_ya%C5%9F%2C_%C5%9Fehir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
isim = input("Lütfen adınızı girin: ")
yas = int(input("Lütfen yaşınızı girin: "))
sehir = input("Lütfen yaşadığınız şehri girin: ")

print(f"Merhaba {isim}! {yas} yaşındasın ve {sehir} şehrinde yaşıyorsun.")
# Out:
# Lütfen adınızı girin: Tuna
# Lütfen yaşınızı girin: 19
# Lütfen yaşadığınız şehri girin: İzmir
# Merhaba Tuna! 19 yaşındasın ve İzmir şehrinde yaşıyorsun.
